# %%
# This is a comment

print("Hello World")
# Out:
# Hello World

# %% [markdown]
# This is text
#
# ## This is a headline

# %%
2 + 2
# Out:
# 4

# %%
2 ** 16
# Out:
# 65536

# %%
3 > 4
# Out:
# False

# %%
numbers = [1,2,3]

# %%
numbers
# Out:
# [1, 2, 3]

# %%
numbers[2]
# Out:
# 3

# %%
for num in numbers:
    print(num)
    print("In loop")
print(numbers)
print("Out of loop")
# Out:
# 1
# In loop
# 2
# In loop
# 3
# In loop
# [1, 2, 3]
# Out of loop

# %%
numbers.append(4)

# %%
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
print(numbers.pop())
# Out:
# 3

# %%
help(numbers)
# Out:
# Help on list object:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
# ...

# %%
a_tuple = (1,2,3)

# %%
print(a_tuple)
# Out:
# (1, 2, 3)

# %%
a_tuple[0]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2a9e098a49eb> in <module>()
# ----> 1 a_tuple[0]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
translation = {'one':1,'two':2}
translation['one']
# Out:
# 1

# %%
def add_function(a,b):
    result = a+b
    return result

z = add_function(20,22)
print(z)
# Out:
# 42

# %%
import pandas as pd

# %%
surveys_df = pd.read_csv("surveys.csv")

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
all_values = surveys_df['weight'].describe()

# %%
type(all_values)
# Out:
# pandas.core.series.Series

# %%
print(all_values)
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
all_values[2],all_values[3]
# Out:
# (36.631259474583992, 4.0)

# %%
mean = surveys_df['weight'].mean()

# %%
mean/2
# Out:
# 21.336214106495678

# %%
# count the number of samples by species
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
# count the number of samples for one species
species_counts_single = surveys_df.groupby('species_id')['record_id'].count()['DO']
print(species_counts_single)
# Out:
# 3027

# %%
# %matplotlib inline

# %%
species_counts.plot(kind='bar')

# %%
surveys_df.groupby('plot_id').mean()['weight'].plot(kind='bar')

# %%
surveys_df.groupby('species_id')['weight'].mean()
# Out:
# species_id
# AB           NaN
# AH           NaN
# AS           NaN
# BA      8.600000
# CB           NaN
# CM           NaN
# CQ           NaN
# CS           NaN
# CT           NaN
# CU           NaN
# CV           NaN
# DM     43.157864
# DO     48.870523
# DS    120.130546
# DX           NaN
# NL    159.245660
# OL     31.575258
# OT     24.230556
# OX     21.000000
# PB     31.735943
# PC           NaN
# PE     21.586508
# PF      7.923127
# PG           NaN
# PH     31.064516
# PI     19.250000
# PL     19.138889
# PM     21.364155
# PP     17.173942
# PU           NaN
# PX     19.000000
# RF     13.386667
# RM     10.585010
# RO     10.250000
# RX     15.500000
# SA           NaN
# SC           NaN
# SF     58.878049
# SH     73.148936
# SO     55.414634
# SS     93.500000
# ST           NaN
# SU           NaN
# UL           NaN
# UP           NaN
# UR           NaN
# US           NaN
# ZL           NaN
# Name: weight, dtype: float64

# %%
pd.isnull(surveys_df)
# Out:
#       record_id  month    day   year plot_id species_id    sex  \
# 0         False  False  False  False   False      False  False
# 1         False  False  False  False   False      False  False
# 2         False  False  False  False   False      False  False
# 3         False  False  False  False   False      False  False
# 4         False  False  False  False   False      False  False
# 5         False  False  False  False   False      False  False
# 6         False  False  False  False   False      False  False
# 7         False  False  False  False   False      False  False
# 8         False  False  False  False   False      False  False
# 9         False  False  False  False   False      False  False
# 10        False  False  False  False   False      False  False
# 11        False  False  False  False   False      False  False
# 12        False  False  False  False   False      False  False
# 13        False  False  False  False   False      False   True
# ...

# %%
len(surveys_df)
# Out:
# 35549

# %%
len(surveys_df[pd.isnull(surveys_df).any(axis=1)])
# Out:
# 4873

# %%
surveys_df[pd.isnull(surveys_df['weight'])]['weight']
# Out:
# 3266

# %%
len(surveys_df[pd.isnull(surveys_df['weight'])]['weight'])
# Out:
# 3266

# %%
len(surveys_df[pd.notnull(surveys_df['weight'])]['weight'])
# Out:
# 32283

# %%
pd.isnull(surveys_df)
# Out:
#       record_id  month    day   year plot_id species_id    sex  \
# 0         False  False  False  False   False      False  False
# 1         False  False  False  False   False      False  False
# 2         False  False  False  False   False      False  False
# 3         False  False  False  False   False      False  False
# 4         False  False  False  False   False      False  False
# 5         False  False  False  False   False      False  False
# 6         False  False  False  False   False      False  False
# 7         False  False  False  False   False      False  False
# 8         False  False  False  False   False      False  False
# 9         False  False  False  False   False      False  False
# 10        False  False  False  False   False      False  False
# 11        False  False  False  False   False      False  False
# 12        False  False  False  False   False      False  False
# 13        False  False  False  False   False      False   True
# ...

# %%
len(surveys_df[pd.isnull(surveys_df.weight)])
# Out:
# 3266

# %%
len(surveys_df[pd.isnull(surveys_df['weight'])])
# Out:
# 3266

# %%
surveys_df['weight'].mean()
# Out:
# 42.672428212991356

# %%
df1 = surveys_df.copy()

# %%
df1['weight']=df1['weight'].fillna(0)

# %%
df1['weight'].mean()
# Out:
# 38.751976145601844

# %%
len(surveys_df[surveys_df.weight>20])
# Out:
# 24055

# %%
len(surveys_df.weight>20)
# Out:
# 35549

# %%
surveys_df.weight>20
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 35519     True
# 35520     True
# 35521     True
# 35522     True
# 35523     True
# 35524     True
# 35525     True
# 35526     True
# 35527    False
# 35528     True
# 35529    False
# 35530    False
# 35531     True
# 35532     True
# 35533     True
# 35534     True
# 35535     True
# 35536     True
# 35537     True
# 35538     True
# 35539     True
# 35540     True
# 35541     True
# 35542     True
# 35543    False
# 35544    False
# 35545    False
# ...

# %%
species_df = pd.read_csv("species.csv")
print(species_df)
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
surveys_sub = surveys_df.head(10)
surveys_sub_last10 = surveys_df[-11:-1]
surveys_sub_last10=surveys_sub_last10.reset_index(drop=True)

# %%
surveys_df.head(10)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
surveys_df[0:9]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN

# %%
surveys_df[-10:]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# ...

# %%
surveys_sub_last10 = surveys_df.tail(10)

# %%
surveys_sub_last10 = surveys_sub_last10.reset_index(drop=True)
surveys_sub_last10
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# 2      35542     12   31  2002       15         PB    F             26.0
# 3      35543     12   31  2002       15         PB    F             27.0
# 4      35544     12   31  2002       15         US  NaN              NaN
# 5      35545     12   31  2002       15         AH  NaN              NaN
# 6      35546     12   31  2002       15         AH  NaN              NaN
# 7      35547     12   31  2002       10         RM    F             15.0
# 8      35548     12   31  2002        7         DO    M             36.0
# 9      35549     12   31  2002        5        NaN  NaN              NaN
#
#    weight
# 0    23.0
# 1    31.0
# 2    29.0
# 3    34.0
# 4     NaN
# 5     NaN
# 6     NaN
# 7    14.0
# 8    51.0
# 9     NaN

# %%
vertical_stack = pd.concat([surveys_sub,surveys_sub_last10], axis=0)
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
horizontal_stack = pd.concat([surveys_sub,surveys_sub_last10], axis=1)
horizontal_stack
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight  record_id  month  day  year  plot_id species_id  sex  \
# 0     NaN      35540     12   31  2002       15         PB    F
# ...

# %%
vertical_stack.to_csv('out.csv')
